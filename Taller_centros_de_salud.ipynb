# %% [markdown]
# # Taller: Integración y análisis de datos de un conglomerado de centros de salud
#
# ## Contexto
#
# Un conglomerado de centros de salud distribuidos en distintas provincias de Argentina necesita consolidar la información de sus consultas médicas para tomar decisiones de gestión. Los datos provienen de tres fuentes distintas:
#
# - **consultas.csv**: registro de consultas médicas realizadas durante el año.
# - **prestaciones.csv**: catálogo de prestaciones médicas con sus categorías y costos de referencia.
# - **sucursales.txt**: listado de centros de salud con su ubicación geográfica.
#
# El objetivo del taller es integrar estas fuentes, limpiar los datos y responder una pregunta de análisis asignada a cada grupo.
#
# ---

# %%
# %cd /content
# !git clone https://github.com/joelmoraesDev/Taller_centro_de_salud.git
# Out:
# /content
# Cloning into 'Taller_centro_de_salud'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 2), reused 11 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 22.06 KiB | 4.41 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/Taller_centro_de_salud/consultas.csv" "/content/Taller_centro_de_salud/data/"
# !cp "/content/drive/MyDrive/Taller_centro_de_salud/prestaciones.csv" "/content/Taller_centro_de_salud/data"
# !cp "/content/drive/MyDrive/Taller_centro_de_salud/sucursales.txt" "/content/Taller_centro_de_salud/data/"

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	data/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add data/prestaciones.csv
# !git add data/consultas.csv
# !git add data/sucursales.txt

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   data/consultas.csv
# 	new file:   data/prestaciones.csv
# 	new file:   data/sucursales.txt

# %%
# !git config --global user.name "Joel Moraes"
# !git config --global user.email "joelmoraes.dev@gmail.com"

# %%
# !git commit -m "Agrega archivos de datos del proyecto"
# Out:
# [main 57c90db] Agrega archivos de datos del proyecto
#  3 files changed, 674 insertions(+)
#  create mode 100644 data/consultas.csv
#  create mode 100644 data/prestaciones.csv
#  create mode 100644 data/sucursales.txt

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
from google.colab import userdata

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")

# %%
# !gh auth login --with-token <<< "$GITHUB_TOKEN"

# %%
# !gh auth setup-git

# %%
# !git push origin main
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 10.87 KiB | 3.62 MiB/s, done.
# Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/joelmoraesDev/Taller_centro_de_salud.git
#    ca67daf..57c90db  main -> main

# %%
# !git add Taller_centros_de_salud_v3.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git commit -m "Agrega el notebook del proyecto"
# Out:
# [main 60a7cc8] Agrega el notebook del proyecto
#  1 file changed, 1 insertion(+)
#  create mode 100644 Taller_centros_de_salud_v3.ipynb

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 5.51 KiB | 5.51 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/joelmoraesDev/Taller_centro_de_salud.git
#    57c90db..60a7cc8  main -> main

# %% [markdown]
# ## Parte 1: Lectura y exploración de los datos
#
# ### 1.1 Importar las bibliotecas necesarias

# %%
# Importar la biblioteca necesaria
import pandas as pd

# %% [markdown]
# ### 1.2 Leer el archivo de consultas
#
# Leer el archivo `consultas.csv` en un DataFrame y explorar su contenido con `.shape`, `.dtypes`, `.head()` e `.info()`.
#
# **Preguntas:**
# - ¿Cuántas filas y columnas tiene el dataset?
# - ¿Qué tipo de dato asignó Pandas a cada columna?
# - ¿Hay valores faltantes? ¿En qué columnas?

# %%
# Leer el archivo CSV de consultas
consultas = pd.read_csv("/content/drive/MyDrive/Taller_centro_de_salud/consultas.csv")

# %%
# Explorar el DataFrame: shape, dtypes, head, info
consultas.head(10)
# Out:
#   id_consulta       fecha id_centro id_prestacion     costo    obra_social  \
# 0    CON00001  22/01/2025     CS006          P005     12467  Swiss Medical
# 1    CON00002  28/12/2024     CS001          P002      8423           OSDE
# 2    CON00003  21/06/2024     CS003          P013     $8886         Galeno
# 3    CON00004  19/05/2024     CS003          P002      8076     Particular
# 4    CON00005  30/11/2024     CS004          P002     $9344     Particular
# 5    CON00006  02/02/2025     CS003          P002  $ 10.181           PAMI
# 6    CON00007  06/09/2024     CS006          P005    $14317  Swiss Medical
# 7    CON00008  04/07/2024     CS004          P005    $15483         Medifé
# 8    CON00009  2024-03-17     CS004          P005  $ 11.743     Particular
# 9    CON00010  24/01/2025     CS003          P003     13860           IOMA
#
#    edad_paciente            diagnostico
# 0             12   Contractura muscular
# 1             54   Contractura muscular
# 2             36     Alergia estacional
# 3             59  Hipertensión arterial
# 4              6        Diabetes tipo 2
# 5             21              Gastritis
# 6             69      Cefalea tensional
# 7             30  Hipertensión arterial
# 8             51             Faringitis
# 9             75               Esguince

# %%
consultas.shape
# Out:
# (650, 8)

# %%
consultas.dtypes
# Out:
# id_consulta      object
# fecha            object
# id_centro        object
# id_prestacion    object
# costo            object
# obra_social      object
# edad_paciente     int64
# diagnostico      object
# dtype: object

# %%
consultas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_consulta    650 non-null    object
#  1   fecha          650 non-null    object
#  2   id_centro      650 non-null    object
#  3   id_prestacion  650 non-null    object
#  4   costo          650 non-null    object
#  5   obra_social    650 non-null    object
#  6   edad_paciente  650 non-null    int64
#  7   diagnostico    567 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 40.8+ KB

# %%
#verificar valores faltantes
consultas.isnull().sum()
# Out:
# id_consulta       0
# fecha             0
# id_centro         0
# id_prestacion     0
# costo             0
# obra_social       0
# edad_paciente     0
# diagnostico      83
# dtype: int64

# %% [markdown]
# #### Observaciones importantes
#
#
# *   El dataset tiene 680 filas y 8 columnas
# *   la columna `costo` es de tipo `object`(texto) no numérica. Esto se debe a que algunos valores tienen `$`, puntos y espacios
#
#
# *   La columna `diagnostico` tiene 83 valores faltantes. (puede verificarse con `isnull().sum()`)
# *   La columna `fecha` aparece como `object`.

# %%
# !git add Taller_centros_de_salud_v3.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git commit -m "Lectura y exploracion de archivo consultas.csv"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %% [markdown]
# ### 1.3 Leer el archivo de prestaciones
#
# Leer el archivo `prestaciones.csv` y explorar su contenido.
#
# **Preguntas:**
# - ¿Qué columnas contiene?
# - ¿Qué columna podría usarse para vincularlo con el archivo de consultas?

# %%
# Leer el archivo CSV de prestaciones
prestaciones = pd.read_csv("Taller_centro_de_salud/data/prestaciones.csv")

# %%
# Explorar el DataFrame de prestaciones
prestaciones.head()
# Out:
#   id_prestacion         nombre_prestacion      categoria  costo_base
# 0          P001  Consulta clínica general        Clínica        8500
# 1          P002       Consulta pedíatrica      Pediatria        9200
# 2          P003      Control Cardiológico    Cardiología       15000
# 3          P004    Consulta dermatológica   Dermatología       11000
# 4          P005   Consulta traumatologica  Traumatología       13500

# %%
print(prestaciones.shape)
print(prestaciones.dtypes)
# Out:
# (15, 4)
# id_prestacion        object
# nombre_prestacion    object
# categoria            object
# costo_base            int64
# dtype: object

# %%
prestaciones.isnull().sum()
# Out:
# id_prestacion        0
# nombre_prestacion    0
# categoria            0
# costo_base           0
# dtype: int64

# %% [markdown]
# #### Observaciones importantes
#
#
# *   15 filas (una por prestación), y 4 columnas `id_prestacion`, `nombre_prestacion`, `categoria`, `costo_base`.
# *   Todos los tipos son correctos desde la lectura, strings y enteros.
#
#
# *   La columna clave para el join con `consultas` es `id_prestaciones`.

# %% [markdown]
# ### 1.4 Leer el archivo de centros de salud
#
# Leer el archivo `sucursales.txt`. Tener en cuenta que está delimitado por tabulaciones.
#
# **Preguntas:**
# - ¿Qué separador se debe indicar para leer correctamente este archivo?
# - ¿Los nombres de los centros están limpios o tienen algún problema?

# %%
sucursales0 = pd.read_csv("Taller_centro_de_salud/data/sucursales.txt")
sucursales0.head()
# Out:
#   id_centro\tnombre_centro\tlocalidad\tprovincia\ttelefono
# 0  CS001\tCentro de Salud  Rivadavia\tCiudad Autó...
# 1  CS002\tCentro Médico del Sur\tLa Plata\tBuenos...
# 2  CS003\tClínica San Martín \tCórdoba\tCórdoba\t...
# 3  CS004\tCentro de Salud Belgrano\tRosario\tSant...
# 4  CS005\tPoliclínico  Norte\tMendoza\tMendoza\t0...

# %%
sucursales0 = pd.read_csv("Taller_centro_de_salud/data/sucursales.txt", sep= "\t")
sucursales0.head(10)
# Out:
#   id_centro                   nombre_centro                        localidad  \
# 0     CS001      Centro de Salud  Rivadavia  Ciudad Autónoma de Buenos Aires
# 1     CS002           Centro Médico del Sur                         La Plata
# 2     CS003             Clínica San Martín                           Córdoba
# 3     CS004        Centro de Salud Belgrano                          Rosario
# 4     CS005              Policlínico  Norte                          Mendoza
# 5     CS006  Centro Integral de Salud Oeste  Ciudad Autónoma de Buenos Aires
#
#       provincia       telefono
# 0  Buenos Aires  011-4555-1234
# 1  Buenos Aires  0221-422-5678
# 2       Córdoba  0351-489-0012
# 3      Santa Fe  0341-456-3344
# 4       Mendoza  0261-411-7788
# 5  Buenos Aires  011-4600-9900

# %%
print(sucursales0.shape)
print(sucursales0.dtypes)
# Out:
# (6, 5)
# id_centro        object
# nombre_centro    object
# localidad        object
# provincia        object
# telefono         object
# dtype: object

# %% [markdown]
# #### Observaciones importantes
#
#
# *   6 centros de salud, el separador es una tabulacion `\t`, no una coma.
# *   Algunos nombres tienen espacios dobles o espacios al inicio/fina: hay que limpiarlos antes del join para no perder registros por discrepancia en los strings.

# %%
import json
from google.colab import _message

# %%
# %cd /content/Taller_centro_de_salud/
# !git pull origin main
# Out:
# /content/Taller_centro_de_salud
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 10.63 KiB | 3.54 MiB/s, done.
# From https://github.com/joelmoraesDev/Taller_centro_de_salud
#  * branch            main       -> FETCH_HEAD
#    1fc0327..01dd14f  main       -> origin/main
# Updating 1fc0327..01dd14f
# Fast-forward
#  Taller_centros_de_salud_v3.ipynb | 1971 +++++++++++++++++++++++++++++++++++++-
#  1 file changed, 1970 insertions(+), 1 deletion(-)

# %%
nb = _message.blocking_request('get_ipynb')['ipynb']
with open("Taller_centros_de_salud.ipynb", "w") as f:
  json.dump(nb,f)

# %%
# !git config user.name "Joel Moraes"
# !git config user.email "joelmoraes.dev@gmail.com"
# !git add data/sucursales.txt

# %%
# !cat data/sucursales.txt
# !git log --oneline -3 -- data/sucursales.txt
# Out:
# id_centro	nombre_centro	localidad	provincia	telefono
# CS001	Centro de Salud  Rivadavia	Ciudad Autónoma de Buenos Aires	Buenos Aires	011-4555-1234
# CS002	Centro Médico del Sur	La Plata	Buenos Aires	0221-422-5678
# CS003	Clínica San Martín 	Córdoba	Córdoba	0351-489-0012
# CS004	Centro de Salud Belgrano	Rosario	Santa Fe	0341-456-3344
# CS005	Policlínico  Norte	Mendoza	Mendoza	0261-411-7788
# CS006	Centro Integral de Salud Oeste	Ciudad Autónoma de Buenos Aires	Buenos Aires	011-4600-9900
# 57c90db Agrega archivos de datos del proyecto

# %% [markdown]
# ---
#
# ## Parte 2: Limpieza de datos
#
# ### 2.1 Limpiar la columna de costos
#
# La columna `costo` del archivo de consultas no es numérica: contiene símbolos de pesos (`$`), espacios y puntos como separadores de miles.
#
# **Tareas:**
# 1. Eliminar los caracteres no numéricos de la columna `costo`.
# 2. Convertir la columna a tipo numérico (`int` o `float`).
# 3. Verificar que la conversión fue exitosa.

# %% [markdown]
# ### 2.2 Limpiar los nombres de los centros de salud
#
# Algunos nombres de centros tienen espacios dobles o espacios al inicio/final.
#
# **Tareas:**
# 1. Eliminar espacios extra en la columna `nombre_centro`.
# 2. Verificar el resultado comparando antes y después.

# %%
# Limpiar los nombres de centros de salud
# Sugerencia: investigar .str.strip() y .str.replace() con expresiones regulares

# %% [markdown]
# ### 2.3 Diagnóstico de los datos limpios
#
# Redactar un breve resumen que describa:
# - Qué problemas se encontraron en cada archivo.
# - Cómo se resolvió cada uno.
# - El estado final de cada DataFrame (cantidad de filas, columnas y tipos de datos).

# %% [markdown]
# *Escribir el diagnóstico aquí.*

# %% [markdown]
# ---
#
# ## Parte 3: Integración de los datos
#
# ### 3.1 Unir consultas con prestaciones
#
# Realizar un join entre el DataFrame de consultas y el de prestaciones.
#
# **Preguntas guía:**
# - ¿Qué columna tienen en común ambos DataFrames?
# - ¿Qué tipo de join conviene usar: `inner`, `left` o `right`? ¿Por qué?
# - ¿Se pierden registros después del join? ¿Qué significaría si eso ocurriera?

# %%
# Unir consultas con prestaciones
# Sugerencia: usar pd.merge() con los parámetros on= y how=

# %% [markdown]
# ### 3.2 Unir con centros de salud
#
# Agregar al DataFrame consolidado la información de los centros de salud (nombre del centro, localidad, provincia).
#
# **Tareas:**
# 1. Realizar el segundo join.
# 2. Verificar la cantidad de filas resultante.
# 3. Explorar el DataFrame consolidado final.

# %%
# Unir con centros de salud

# %%
# Verificar el DataFrame consolidado

# %% [markdown]
# ### 4.1 Pregunta de análisis
#
# Cada grupo debe responder **una** de las siguientes preguntas:
#
# 1- ¿Cuál es la categoría de prestación más frecuente en cada centro de salud?
#
# 2- ¿Cuál es el costo promedio de consulta por obra social?
#
# 3- ¿Qué obra social concentra el mayor gasto total?
#
# 4-¿En qué provincia se realizaron más consultas?
#
# ---
#
# ### 4.2 Resolución
#
# Utilizar `groupby()` y funciones de agregación (`.sum()`, `.mean()`, `.count()`, etc.) para responder la pregunta asignada.

# %%
# Resolver la pregunta asignada al grupo

# %%
# Tabla resumen con el resultado

# %% [markdown]
# ### 4.3 Interpretación
#
# Escribir una breve interpretación del resultado obtenido (3 a 5 oraciones). ¿Qué le diría este resultado al equipo de gestión de los centros de salud?

# %% [markdown]
# *Escribir la interpretación aquí.*
